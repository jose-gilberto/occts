# %%
import sys
sys.path.append('../../../')

# %%
import numpy as np

from occts.classifiers.deep import LinearClassifier, OneClassTrainer
from occts.classifiers.deep_task import OneClassTask
from occts.utils.data import load_ucr_dataset, create_datasets, create_dataloaders

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from typing import Tuple, Optional

# %%
DATASETS = [
    'Yoga', 'WormsTwoClass', 'Wine', 'Wafer', 'TwoLeadECG', 'Strawberry', 'SemgHandGenderCh2', 'BeetleFly',
    'BirdChicken', 'Computers', 'DistalPhalanxOutlineCorrect', 'Earthquakes', 'ECG200', 'ECGFiveDays',
    'FordA', 'FordB', 'HandOutlines', 'ItalyPowerDemand', 'MiddlePhalanxOutlineCorrect', 'Chinatown',
    'FreezerRegularTrain', 'FreezerSmallTrain', 'GunPointAgeSpan', 'GunPointMaleVersusFemale',
    'GunPointOldVersusYoung', 'PowerCons', 'Coffee', 'Ham', 'Herring', 'Lightning2', 'MoteStrain',
    'PhalangesOutlinesCorrect', 'ProximalPhalanxOutlineCorrect', 'ShapeletSim', 'SonyAIBORobotSurface1',
    'SonyAIBORobotSurface2', 'ToeSegmentation1', 'ToeSegmentation2', 'HouseTwenty'
]

# %%
dataset_list = []
dataset_label = []
dataset_roc_auc = []
dataset_acc = []

# %%
for dataset in DATASETS:
    print(f'Testing with dataset: {dataset}...')
    x_train, x_test, y_train, y_test = load_ucr_dataset(dataset=dataset)

    # Get unique labels to do the one class classification task
    unique_labels = np.unique(y_train)

    for label in unique_labels:
        print(f'\tClassifying the label {label}...')

        train_dataset, _, test_dataset = create_datasets(x_train, x_test, y_train, y_test, label)
        train_loader, _, test_loader = create_dataloaders(train_dataset=train_dataset, test_dataset=test_dataset)

        model = LinearClassifier(input_dim=x_train.shape[2], latent_dim=32)
        octask = OneClassTask(model=model, objective='soft-boundary', nu=0.1)

        octask.train(dataloader=train_loader, epochs=150, lr=1e-3, weight_decay=1e-6)
        octask.test(dataloader=test_loader)

        dataset_list.append(dataset)
        dataset_label.append(label)
        dataset_acc.append(octask.trainer.test_acc)
        dataset_roc_auc.append(octask.trainer.test_auc)
# Out:
# Testing with dataset: Yoga...
# 	Classifying the label 1...
# 			Test set AUC 0.5544948495701014
# 			Test set Accuracy 0.4643333333333333
# 	Classifying the label 2...
# 			Test set AUC 0.5438459968077565
# 			Test set Accuracy 0.5356666666666666
# Testing with dataset: WormsTwoClass...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5714285714285714
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5714285714285714
# Testing with dataset: Wine...
# 	Classifying the label 1...
# 			Test set AUC 0.45816186556927296
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# Testing with dataset: Wafer...
# 	Classifying the label -1...
# 			Test set AUC 0.6746420059969892
# 			Test set Accuracy 0.10788449059052563
# 	Classifying the label 1...
# 			Test set AUC 0.1427748312406767
# 			Test set Accuracy 0.8921155094094744
# Testing with dataset: TwoLeadECG...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.4995610184372256
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.4995610184372256
# Testing with dataset: Strawberry...
# 	Classifying the label 1...
# 			Test set AUC 0.48599439775910364
# 			Test set Accuracy 0.3567567567567568
# 	Classifying the label 2...
# 			Test set AUC 0.23653552330022917
# 			Test set Accuracy 0.6432432432432432
# Testing with dataset: SemgHandGenderCh2...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.65
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.35
# Testing with dataset: BeetleFly...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# Testing with dataset: BirdChicken...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# Testing with dataset: Computers...
# 	Classifying the label 1...
# 			Test set AUC 0.5050239999999999
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.408128
# 			Test set Accuracy 0.5
# Testing with dataset: DistalPhalanxOutlineCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.6263029975695382
# 			Test set Accuracy 0.4166666666666667
# 	Classifying the label 1...
# 			Test set AUC 0.41296246286794497
# 			Test set Accuracy 0.5833333333333334
# Testing with dataset: Earthquakes...
# 	Classifying the label 0...
# 			Test set AUC 0.5994505494505494
# 			Test set Accuracy 0.7266187050359713
# 	Classifying the label 1...
# 			Test set AUC 0.4684065934065934
# 			Test set Accuracy 0.2517985611510791
# Testing with dataset: ECG200...
# 	Classifying the label -1...
# 			Test set AUC 0.5694444444444445
# 			Test set Accuracy 0.36
# 	Classifying the label 1...
# 			Test set AUC 0.48220486111111116
# 			Test set Accuracy 0.65
# Testing with dataset: ECGFiveDays...
# 	Classifying the label 1...
# 			Test set AUC 0.30758023785370486
# 			Test set Accuracy 0.49709639953542395
# 	Classifying the label 2...
# 			Test set AUC 0.6123869547387278
# 			Test set Accuracy 0.502903600464576
# Testing with dataset: FordA...
# 	Classifying the label -1...
# 			Test set AUC 0.46604344618863447
# 			Test set Accuracy 0.5159090909090909
# 	Classifying the label 1...
# 			Test set AUC 0.6509321880048442
# 			Test set Accuracy 0.48409090909090907
# Testing with dataset: FordB...
# 	Classifying the label -1...
# 			Test set AUC 0.4895889859702821
# 			Test set Accuracy 0.49506172839506174
# 	Classifying the label 1...
# 			Test set AUC 0.5459700382296093
# 			Test set Accuracy 0.5049382716049383
# Testing with dataset: HandOutlines...
# 	Classifying the label 0...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.35945945945945945
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.6405405405405405
# Testing with dataset: ItalyPowerDemand...
# 	Classifying the label 1...
# 			Test set AUC 0.46216963597624555
# 			Test set Accuracy 0.49854227405247814
# 	Classifying the label 2...
# 			Test set AUC 0.12137902896776825
# 			Test set Accuracy 0.5014577259475219
# Testing with dataset: MiddlePhalanxOutlineCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.4410602409638555
# 			Test set Accuracy 0.42955326460481097
# 	Classifying the label 1...
# 			Test set AUC 0.3493975903614458
# 			Test set Accuracy 0.570446735395189
# Testing with dataset: Chinatown...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.27405247813411077
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.7259475218658892
# Testing with dataset: FreezerRegularTrain...
# 	Classifying the label 1...
# 			Test set AUC 0.7757675592489996
# 			Test set Accuracy 0.5080701754385964
# 	Classifying the label 2...
# 			Test set AUC 0.1934665435518621
# 			Test set Accuracy 0.4982456140350877
# Testing with dataset: FreezerSmallTrain...
# 	Classifying the label 1...
# 			Test set AUC 0.49964912280701756
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.6382165589412127
# 			Test set Accuracy 0.6298245614035087
# Testing with dataset: GunPointAgeSpan...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.4936708860759494
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.4936708860759494
# Testing with dataset: GunPointMaleVersusFemale...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.47468354430379744
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.47468354430379744
# Testing with dataset: GunPointOldVersusYoung...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.47619047619047616
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5238095238095238
# Testing with dataset: PowerCons...
# 	Classifying the label 1...
# 			Test set AUC 0.17407407407407405
# 			Test set Accuracy 0.4444444444444444
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# Testing with dataset: Coffee...
# 	Classifying the label 0...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5357142857142857
# 	Classifying the label 1...
# 			Test set AUC 0.08717948717948718
# 			Test set Accuracy 0.4642857142857143
# Testing with dataset: Ham...
# 	Classifying the label 1...
# 			Test set AUC 0.4386347131445171
# 			Test set Accuracy 0.4857142857142857
# 	Classifying the label 2...
# 			Test set AUC 0.3395061728395061
# 			Test set Accuracy 0.5142857142857142
# Testing with dataset: Herring...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.59375
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.40625
# Testing with dataset: Lightning2...
# 	Classifying the label -1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5409836065573771
# 	Classifying the label 1...
# 			Test set AUC 0.24567099567099568
# 			Test set Accuracy 0.5409836065573771
# Testing with dataset: MoteStrain...
# 	Classifying the label 1...
# 			Test set AUC 0.7099120611079016
# 			Test set Accuracy 0.5391373801916933
# 	Classifying the label 2...
# 			Test set AUC 0.5018627639771487
# 			Test set Accuracy 0.5407348242811502
# Testing with dataset: PhalangesOutlinesCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.4919373310733428
# 			Test set Accuracy 0.38694638694638694
# 	Classifying the label 1...
# 			Test set AUC 0.4272470108571167
# 			Test set Accuracy 0.6130536130536131
# Testing with dataset: ProximalPhalanxOutlineCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.5358313305658728
# 			Test set Accuracy 0.3161512027491409
# 	Classifying the label 1...
# 			Test set AUC 0.24431942320297137
# 			Test set Accuracy 0.6838487972508591
# Testing with dataset: ShapeletSim...
# 	Classifying the label 0...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5
# Testing with dataset: SonyAIBORobotSurface1...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5707154742096506
# 	Classifying the label 2...
# 			Test set AUC 0.47674418604651164
# 			Test set Accuracy 0.4292845257903494
# Testing with dataset: SonyAIBORobotSurface2...
# 	Classifying the label 1...
# 			Test set AUC 0.68633864504706
# 			Test set Accuracy 0.3830010493179433
# 	Classifying the label 2...
# 			Test set AUC 0.47903037927499764
# 			Test set Accuracy 0.6169989506820567
# Testing with dataset: ToeSegmentation1...
# 	Classifying the label 0...
# 			Test set AUC 0.6408179012345678
# 			Test set Accuracy 0.5657894736842105
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.5263157894736842
# Testing with dataset: ToeSegmentation2...
# 	Classifying the label 0...
# 			Test set AUC 0.5640723270440251
# 			Test set Accuracy 0.8153846153846154
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.18461538461538463
# Testing with dataset: HouseTwenty...
# 	Classifying the label 1...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.42016806722689076
# 	Classifying the label 2...
# 			Test set AUC 0.5
# 			Test set Accuracy 0.42016806722689076

# %%
import pandas as pd

results = pd.DataFrame({
    'dataset': dataset_list,
    'label': dataset_label,
    'accurcy': dataset_acc,
    'roc_auc': dataset_roc_auc
})

results.to_csv('./linear_results.csv', index=False)
