# %%
import sys
sys.path.append('../../../')

# %%
import numpy as np

from occts.classifiers.deep import FCNClassifier, OneClassTrainer
from occts.classifiers.deep_task import OneClassTask
from occts.utils.data import load_ucr_dataset, create_datasets, create_dataloaders

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from typing import Tuple, Optional

# %%
DATASETS = [
    'Yoga', 'WormsTwoClass', 'Wine', 'Wafer', 'TwoLeadECG', 'Strawberry', 'SemgHandGenderCh2', 'BeetleFly',
    'BirdChicken', 'Computers', 'DistalPhalanxOutlineCorrect', 'Earthquakes', 'ECG200', 'ECGFiveDays',
    'FordA', 'FordB', 'HandOutlines', 'ItalyPowerDemand', 'MiddlePhalanxOutlineCorrect', 'Chinatown',
    'FreezerRegularTrain', 'FreezerSmallTrain', 'GunPointAgeSpan', 'GunPointMaleVersusFemale',
    'GunPointOldVersusYoung', 'PowerCons', 'Coffee', 'Ham', 'Herring', 'Lightning2', 'MoteStrain',
    'PhalangesOutlinesCorrect', 'ProximalPhalanxOutlineCorrect', 'ShapeletSim', 'SonyAIBORobotSurface1',
    'SonyAIBORobotSurface2', 'ToeSegmentation1', 'ToeSegmentation2', 'HouseTwenty'
]

# %%
dataset_list = []
dataset_label = []
dataset_roc_auc = []
dataset_acc = []

# %%
for dataset in DATASETS:
    print(f'Testing with dataset: {dataset}...')
    x_train, x_test, y_train, y_test = load_ucr_dataset(dataset=dataset)

    # Get unique labels to do the one class classification task
    unique_labels = np.unique(y_train)

    for label in unique_labels:
        print(f'\tClassifying the label {label}...')

        train_dataset, _, test_dataset = create_datasets(x_train, x_test, y_train, y_test, label)
        train_loader, _, test_loader = create_dataloaders(train_dataset=train_dataset, test_dataset=test_dataset)

        model = FCNClassifier(in_channels=1, latent_dim=32)
        octask = OneClassTask(model=model, objective='soft-boundary', nu=0.1)

        octask.train(dataloader=train_loader, epochs=150, lr=1e-3, weight_decay=1e-6)
        octask.test(dataloader=test_loader)

        dataset_list.append(dataset)
        dataset_label.append(label)
        dataset_acc.append(octask.trainer.test_acc)
        dataset_roc_auc.append(octask.trainer.test_auc)
# Out:
# Testing with dataset: Yoga...
# 	Classifying the label 1...
# 			Test set AUC 0.6122732964314863
# 			Test set Accuracy 0.49333333333333335
# 	Classifying the label 2...
# 			Test set AUC 0.6938698291886135
# 			Test set Accuracy 0.6453333333333333
# Testing with dataset: WormsTwoClass...
# 	Classifying the label 1...
# 			Test set AUC 0.6577134986225897
# 			Test set Accuracy 0.6363636363636364
# 	Classifying the label 2...
# 			Test set AUC 0.3650137741046832
# 			Test set Accuracy 0.4805194805194805
# Testing with dataset: Wine...
# 	Classifying the label 1...
# 			Test set AUC 0.35253772290809327
# 			Test set Accuracy 0.4074074074074074
# 	Classifying the label 2...
# 			Test set AUC 0.7722908093278463
# 			Test set Accuracy 0.6111111111111112
# Testing with dataset: Wafer...
# 	Classifying the label -1...
# 			Test set AUC 0.8191239145326491
# 			Test set Accuracy 0.8976314081765088
# 	Classifying the label 1...
# 			Test set AUC 0.9119066077632707
# 			Test set Accuracy 0.9093121349772875
# Testing with dataset: TwoLeadECG...
# 	Classifying the label 1...
# 			Test set AUC 0.8499676255665526
# 			Test set Accuracy 0.6540825285338016
# 	Classifying the label 2...
# 			Test set AUC 0.7960749853544229
# 			Test set Accuracy 0.5276558384547849
# Testing with dataset: Strawberry...
# 	Classifying the label 1...
# 			Test set AUC 0.9079449961802903
# 			Test set Accuracy 0.8216216216216217
# 	Classifying the label 2...
# 			Test set AUC 0.6215304303539597
# 			Test set Accuracy 0.3567567567567568
# Testing with dataset: SemgHandGenderCh2...
# 	Classifying the label 1...
# 			Test set AUC 0.3996214896214896
# 			Test set Accuracy 0.4766666666666667
# 	Classifying the label 2...
# 			Test set AUC 0.4930769230769231
# 			Test set Accuracy 0.38333333333333336
# Testing with dataset: BeetleFly...
# 	Classifying the label 1...
# 			Test set AUC 0.9400000000000001
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.64
# 			Test set Accuracy 0.5
# Testing with dataset: BirdChicken...
# 	Classifying the label 1...
# 			Test set AUC 0.75
# 			Test set Accuracy 0.5
# 	Classifying the label 2...
# 			Test set AUC 0.7100000000000001
# 			Test set Accuracy 0.5
# Testing with dataset: Computers...
# 	Classifying the label 1...
# 			Test set AUC 0.48704000000000003
# 			Test set Accuracy 0.508
# 	Classifying the label 2...
# 			Test set AUC 0.38304000000000005
# 			Test set Accuracy 0.464
# Testing with dataset: DistalPhalanxOutlineCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.40081015392924657
# 			Test set Accuracy 0.37318840579710144
# 	Classifying the label 1...
# 			Test set AUC 0.7156899810964084
# 			Test set Accuracy 0.4166666666666667
# Testing with dataset: Earthquakes...
# 	Classifying the label 0...
# 			Test set AUC 0.38901098901098896
# 			Test set Accuracy 0.2589928057553957
# 	Classifying the label 1...
# 			Test set AUC 0.44532967032967036
# 			Test set Accuracy 0.4460431654676259
# Testing with dataset: ECG200...
# 	Classifying the label -1...
# 			Test set AUC 0.6397569444444444
# 			Test set Accuracy 0.68
# 	Classifying the label 1...
# 			Test set AUC 0.8741319444444444
# 			Test set Accuracy 0.46
# Testing with dataset: ECGFiveDays...
# 	Classifying the label 1...
# 			Test set AUC 0.7004705272927414
# 			Test set Accuracy 0.6527293844367015
# 	Classifying the label 2...
# 			Test set AUC 0.7808540717877878
# 			Test set Accuracy 0.5447154471544715
# Testing with dataset: FordA...
# 	Classifying the label -1...
# 			Test set AUC 0.5210945884148093
# 			Test set Accuracy 0.5159090909090909
# 	Classifying the label 1...
# 			Test set AUC 0.5578673542314418
# 			Test set Accuracy 0.5159090909090909
# Testing with dataset: FordB...
# 	Classifying the label -1...
# 			Test set AUC 0.557466358553494
# 			Test set Accuracy 0.5049382716049383
# 	Classifying the label 1...
# 			Test set AUC 0.4703034589565207
# 			Test set Accuracy 0.49506172839506174
# Testing with dataset: HandOutlines...
# 	Classifying the label 0...
# 			Test set AUC 0.28159005107705976
# 			Test set Accuracy 0.35945945945945945
# 	Classifying the label 1...
# 			Test set AUC 0.4920846419847086
# 			Test set Accuracy 0.35945945945945945
# Testing with dataset: ItalyPowerDemand...
# 	Classifying the label 1...
# 			Test set AUC 0.971387340012391
# 			Test set Accuracy 0.7308066083576288
# 	Classifying the label 2...
# 			Test set AUC 0.8415914894903062
# 			Test set Accuracy 0.6666666666666666
# Testing with dataset: MiddlePhalanxOutlineCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.5929156626506024
# 			Test set Accuracy 0.48109965635738833
# 	Classifying the label 1...
# 			Test set AUC 0.7220240963855421
# 			Test set Accuracy 0.42955326460481097
# Testing with dataset: Chinatown...
# 	Classifying the label 1...
# 			Test set AUC 0.9076305220883534
# 			Test set Accuracy 0.8717201166180758
# 	Classifying the label 2...
# 			Test set AUC 0.9876100145261899
# 			Test set Accuracy 0.3819241982507289
# Testing with dataset: FreezerRegularTrain...
# 	Classifying the label 1...
# 			Test set AUC 0.8457218836565098
# 			Test set Accuracy 0.6603508771929825
# 	Classifying the label 2...
# 			Test set AUC 0.6382928901200369
# 			Test set Accuracy 0.4957894736842105
# Testing with dataset: FreezerSmallTrain...
# 	Classifying the label 1...
# 			Test set AUC 0.6505524161280394
# 			Test set Accuracy 0.6252631578947369
# 	Classifying the label 2...
# 			Test set AUC 0.7182842720837181
# 			Test set Accuracy 0.6975438596491228
# Testing with dataset: GunPointAgeSpan...
# 	Classifying the label 1...
# 			Test set AUC 0.551121794871795
# 			Test set Accuracy 0.6044303797468354
# 	Classifying the label 2...
# 			Test set AUC 0.5907451923076923
# 			Test set Accuracy 0.4936708860759494
# Testing with dataset: GunPointMaleVersusFemale...
# 	Classifying the label 1...
# 			Test set AUC 0.03393574297188755
# 			Test set Accuracy 0.19936708860759494
# 	Classifying the label 2...
# 			Test set AUC 0.25289156626506026
# 			Test set Accuracy 0.4936708860759494
# Testing with dataset: GunPointOldVersusYoung...
# 	Classifying the label 1...
# 			Test set AUC 0.014787878787878787
# 			Test set Accuracy 0.21904761904761905
# 	Classifying the label 2...
# 			Test set AUC 0.999919191919192
# 			Test set Accuracy 0.8825396825396825
# Testing with dataset: PowerCons...
# 	Classifying the label 1...
# 			Test set AUC 0.9182716049382716
# 			Test set Accuracy 0.8277777777777777
# 	Classifying the label 2...
# 			Test set AUC 0.47530864197530864
# 			Test set Accuracy 0.5222222222222223
# Testing with dataset: Coffee...
# 	Classifying the label 0...
# 			Test set AUC 0.9384615384615385
# 			Test set Accuracy 0.8214285714285714
# 	Classifying the label 1...
# 			Test set AUC 0.8358974358974359
# 			Test set Accuracy 0.5714285714285714
# Testing with dataset: Ham...
# 	Classifying the label 1...
# 			Test set AUC 0.6633986928104576
# 			Test set Accuracy 0.638095238095238
# 	Classifying the label 2...
# 			Test set AUC 0.5602759622367465
# 			Test set Accuracy 0.5142857142857142
# Testing with dataset: Herring...
# 	Classifying the label 1...
# 			Test set AUC 0.4817813765182186
# 			Test set Accuracy 0.59375
# 	Classifying the label 2...
# 			Test set AUC 0.5242914979757085
# 			Test set Accuracy 0.515625
# Testing with dataset: Lightning2...
# 	Classifying the label -1...
# 			Test set AUC 0.7348484848484849
# 			Test set Accuracy 0.6721311475409836
# 	Classifying the label 1...
# 			Test set AUC 0.6158008658008658
# 			Test set Accuracy 0.6557377049180327
# Testing with dataset: MoteStrain...
# 	Classifying the label 1...
# 			Test set AUC 0.7696334809679697
# 			Test set Accuracy 0.46086261980830673
# 	Classifying the label 2...
# 			Test set AUC 0.7827305988831118
# 			Test set Accuracy 0.5415335463258786
# Testing with dataset: PhalangesOutlinesCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.45002347794218706
# 			Test set Accuracy 0.6130536130536131
# 	Classifying the label 1...
# 			Test set AUC 0.7005646158779606
# 			Test set Accuracy 0.38694638694638694
# Testing with dataset: ProximalPhalanxOutlineCorrect...
# 	Classifying the label 0...
# 			Test set AUC 0.48175660913261964
# 			Test set Accuracy 0.41924398625429554
# 	Classifying the label 1...
# 			Test set AUC 0.7025344111863666
# 			Test set Accuracy 0.35738831615120276
# Testing with dataset: ShapeletSim...
# 	Classifying the label 0...
# 			Test set AUC 0.7645679012345679
# 			Test set Accuracy 0.5
# 	Classifying the label 1...
# 			Test set AUC 0.9764197530864197
# 			Test set Accuracy 0.5
# Testing with dataset: SonyAIBORobotSurface1...
# 	Classifying the label 1...
# 			Test set AUC 0.6677401857753068
# 			Test set Accuracy 0.4292845257903494
# 	Classifying the label 2...
# 			Test set AUC 0.9454991298845119
# 			Test set Accuracy 0.5956738768718802
# Testing with dataset: SonyAIBORobotSurface2...
# 	Classifying the label 1...
# 			Test set AUC 0.6494595098313298
# 			Test set Accuracy 0.6243441762854145
# 	Classifying the label 2...
# 			Test set AUC 0.8872146118721461
# 			Test set Accuracy 0.4910807974816369
# Testing with dataset: ToeSegmentation1...
# 	Classifying the label 0...
# 			Test set AUC 0.9395061728395061
# 			Test set Accuracy 0.75
# 	Classifying the label 1...
# 			Test set AUC 0.5101080246913581
# 			Test set Accuracy 0.5570175438596491
# Testing with dataset: ToeSegmentation2...
# 	Classifying the label 0...
# 			Test set AUC 0.9430031446540881
# 			Test set Accuracy 0.7384615384615385
# 	Classifying the label 1...
# 			Test set AUC 0.3934748427672956
# 			Test set Accuracy 0.7923076923076923
# Testing with dataset: HouseTwenty...
# 	Classifying the label 1...
# 			Test set AUC 0.17739130434782613
# 			Test set Accuracy 0.29411764705882354
# 	Classifying the label 2...
# 			Test set AUC 0.36869565217391304
# 			Test set Accuracy 0.46218487394957986

# %%
import pandas as pd

results = pd.DataFrame({
    'dataset': dataset_list,
    'label': dataset_label,
    'accurcy': dataset_acc,
    'roc_auc': dataset_roc_auc
})

results.to_csv('./fcn_results.csv', index=False)
